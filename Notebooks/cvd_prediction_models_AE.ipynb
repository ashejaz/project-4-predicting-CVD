# %%
# Import dependencies
import pandas as pd
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier

# %%
# Read in the cardiovascular dataset from Google Sheets
cvd_df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vSDchXr1EhgCSsxlxJ3lWPhh1kT5EJS3yv4DJ2YLeMIC3y4uq-Pp4EQknrs9zAiaI3ulne2Jyi6gR6G/pub?gid=602879552&single=true&output=csv")
cvd_df.head()
# Out:
#   general_health                  checkup exercise heart_disease skin_cancer  \
# 0           Poor  Within the past 2 years       No            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 2      Very Good     Within the past year      Yes            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 4           Good     Within the past year       No            No          No
#
#   other_cancer depression diabetes arthritis     sex age_category  height_cm  \
# 0           No         No       No       Yes  Female        70-74        150
# 1           No         No      Yes        No  Female        70-74        165
# 2           No         No      Yes        No  Female        60-64        163
# 3           No         No      Yes        No    Male        75-79        180
# 4           No         No       No        No    Male          80+        191
#
#    weight_kg    bmi smoking_history  alcohol_consumption  fruit_consumption  \
# 0      32.66  14.54             Yes                    0                 30
# 1      77.11  28.29              No                    0                 30
# 2      88.45  33.47              No                    4                 12
# 3      93.44  28.73              No                    0                 30
# 4      88.45  24.37             Yes                    0                  8
#
#    green_vegetables_consumption  friedpotato_consumption
# 0                            16                       12
# 1                             0                        4
# 2                             3                       16
# 3                            30                        8
# 4                             4                        0

# %% [markdown]
# # Data Preprocessing

# %%
# Check datatypes
cvd_df.dtypes
# Out:
# general_health                   object
# checkup                          object
# exercise                         object
# heart_disease                    object
# skin_cancer                      object
# other_cancer                     object
# depression                       object
# diabetes                         object
# arthritis                        object
# sex                              object
# age_category                     object
# height_cm                         int64
# weight_kg                       float64
# bmi                             float64
# smoking_history                  object
# alcohol_consumption               int64
# fruit_consumption                 int64
# green_vegetables_consumption      int64
# friedpotato_consumption           int64
# dtype: object

# %%
# Define categorical columns for encoding and numeric columns for scaling
categorical_cols = cvd_df.dtypes[cvd_df.dtypes == 'object'].index.tolist()

numeric_cols = cvd_df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# %%
# Check unique values in each column
cvd_df[categorical_cols].nunique()
# Out:
# general_health      5
# checkup             5
# exercise            2
# heart_disease       2
# skin_cancer         2
# other_cancer        2
# depression          2
# diabetes            2
# arthritis           2
# sex                 2
# age_category       13
# smoking_history     2
# dtype: int64

# %%
# Encode categorical columns using get_dummies
encoded_df = pd.get_dummies(cvd_df, columns=categorical_cols, drop_first=False)
encoded_df.head()
# Out:
#    height_cm  weight_kg    bmi  alcohol_consumption  fruit_consumption  \
# 0        150      32.66  14.54                    0                 30
# 1        165      77.11  28.29                    0                 30
# 2        163      88.45  33.47                    4                 12
# 3        180      93.44  28.73                    0                 30
# 4        191      88.45  24.37                    0                  8
#
#    green_vegetables_consumption  friedpotato_consumption  \
# 0                            16                       12
# 1                             0                        4
# 2                             3                       16
# 3                            30                        8
# 4                             4                        0
#
#    general_health_Excellent  general_health_Fair  general_health_Good  ...  \
# 0                         0                    0                    0  ...
# 1                         0                    0                    0  ...
# 2                         0                    0                    0  ...
# 3                         0                    0                    0  ...
# 4                         0                    0                    1  ...
#
#    age_category_45-49  age_category_50-54  age_category_55-59  \
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0
#
#    age_category_60-64  age_category_65-69  age_category_70-74  \
# 0                   0                   0                   1
# 1                   0                   0                   1
# 2                   1                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0
#
#    age_category_75-79  age_category_80+  smoking_history_No  \
# 0                   0                 0                   0
# 1                   0                 0                   1
# 2                   0                 0                   1
# 3                   1                 0                   1
# 4                   0                 1                   0
#
#    smoking_history_Yes
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    1
#
# [5 rows x 48 columns]

# %%
# Scale numerical columns using StandardScaler
scaler = StandardScaler()
encoded_df[numeric_cols] = scaler.fit_transform(encoded_df[numeric_cols])
encoded_df.head()
# Out:
#    height_cm  weight_kg       bmi  alcohol_consumption  fruit_consumption  \
# 0  -1.945527  -2.388688 -2.162285            -0.624388           0.005697
# 1  -0.537041  -0.299715 -0.040788            -0.624388           0.005697
# 2  -0.724839   0.233220  0.758438            -0.137925          -0.717605
# 3   0.871445   0.467730  0.027100            -0.624388           0.005697
# 4   1.904335   0.233220 -0.645607            -0.624388          -0.878338
#
#    green_vegetables_consumption  friedpotato_consumption  \
# 0                      0.059600                 0.662925
# 1                     -1.012964                -0.268558
# 2                     -0.811858                 1.128667
# 3                      0.998094                 0.197184
# 4                     -0.744823                -0.734299
#
#    general_health_Excellent  general_health_Fair  general_health_Good  ...  \
# 0                         0                    0                    0  ...
# 1                         0                    0                    0  ...
# 2                         0                    0                    0  ...
# 3                         0                    0                    0  ...
# 4                         0                    0                    1  ...
#
#    age_category_45-49  age_category_50-54  age_category_55-59  \
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0
#
#    age_category_60-64  age_category_65-69  age_category_70-74  \
# 0                   0                   0                   1
# 1                   0                   0                   1
# 2                   1                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0
#
#    age_category_75-79  age_category_80+  smoking_history_No  \
# 0                   0                 0                   0
# 1                   0                 0                   1
# 2                   0                 0                   1
# 3                   1                 0                   1
# 4                   0                 1                   0
#
#    smoking_history_Yes
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    1
#
# [5 rows x 48 columns]

# %%
# Assign the target variable 'heart_disease' to y
y = encoded_df['heart_disease_Yes']

# Assign the remaining columns (features) to X
X = encoded_df.drop(columns=['heart_disease_Yes', 'heart_disease_No'])

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
y_train.value_counts()
# Out:
# 0    206364
# 1     18120
# Name: heart_disease_Yes, dtype: int64

# %%
ROS = RandomOverSampler(random_state=78)
X_train_resampled, y_train_resampled = ROS.fit_resample(X_train, y_train)

# %%
y_train_resampled.value_counts()
# Out:
# 1    206364
# 0    206364
# Name: heart_disease_Yes, dtype: int64

# %% [markdown]
# # Model 1: Logistic Regression

# %% [markdown]
# # Model 2: Support Vector Machine

# %% [markdown]
# # Model 3: Decision Tree

# %% [markdown]
# # Model 4: Random Forest

# %% [markdown]
# # Model 5: Neural Network

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = X_train.shape[1]
hidden_nodes_layer1 =  64
hidden_nodes_layer2 = 64

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                3008
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 7233 (28.25 KB)
# Trainable params: 7233 (28.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 7016/7016 [==============================] - 19s 3ms/step - loss: 0.2249 - accuracy: 0.9193
# Epoch 2/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2215 - accuracy: 0.9196
# Epoch 3/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2209 - accuracy: 0.9197
# Epoch 4/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2205 - accuracy: 0.9197
# Epoch 5/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2201 - accuracy: 0.9199
# Epoch 6/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2198 - accuracy: 0.9198
# Epoch 7/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2194 - accuracy: 0.9200
# Epoch 8/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2189 - accuracy: 0.9201
# Epoch 9/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2186 - accuracy: 0.9203
# Epoch 10/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2182 - accuracy: 0.9202
# Epoch 11/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2179 - accuracy: 0.9205
# Epoch 12/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2177 - accuracy: 0.9206
# Epoch 13/100
# 7016/7016 [==============================] - 19s 3ms/step - loss: 0.2172 - accuracy: 0.9208
# Epoch 14/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2168 - accuracy: 0.9207
# Epoch 15/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2164 - accuracy: 0.9212
# Epoch 16/100
# 7016/7016 [==============================] - 18s 2ms/step - loss: 0.2161 - accuracy: 0.9210
# Epoch 17/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2157 - accuracy: 0.9214
# Epoch 18/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2155 - accuracy: 0.9215
# Epoch 19/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2151 - accuracy: 0.9213
# Epoch 20/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2147 - accuracy: 0.9217
# Epoch 21/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2145 - accuracy: 0.9218
# Epoch 22/100
# 7016/7016 [==============================] - 21s 3ms/step - loss: 0.2140 - accuracy: 0.9219
# Epoch 23/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2137 - accuracy: 0.9222
# Epoch 24/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2133 - accuracy: 0.9222
# Epoch 25/100
# 7016/7016 [==============================] - 29s 4ms/step - loss: 0.2130 - accuracy: 0.9222
# Epoch 26/100
# 7016/7016 [==============================] - 20s 3ms/step - loss: 0.2128 - accuracy: 0.9223
# Epoch 27/100
# 7016/7016 [==============================] - 15s 2ms/step - loss: 0.2124 - accuracy: 0.9225
# Epoch 28/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2121 - accuracy: 0.9226
# Epoch 29/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2119 - accuracy: 0.9227
# Epoch 30/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2115 - accuracy: 0.9228
# Epoch 31/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2111 - accuracy: 0.9232
# Epoch 32/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2108 - accuracy: 0.9233
# Epoch 33/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2105 - accuracy: 0.9232
# Epoch 34/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2104 - accuracy: 0.9233
# Epoch 35/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2101 - accuracy: 0.9234
# Epoch 36/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2097 - accuracy: 0.9236
# Epoch 37/100
# 7016/7016 [==============================] - 19s 3ms/step - loss: 0.2094 - accuracy: 0.9238
# Epoch 38/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2092 - accuracy: 0.9239
# Epoch 39/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2090 - accuracy: 0.9240
# Epoch 40/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2089 - accuracy: 0.9239
# Epoch 41/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2083 - accuracy: 0.9241
# Epoch 42/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2081 - accuracy: 0.9243
# Epoch 43/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2079 - accuracy: 0.9244
# Epoch 44/100
# 7016/7016 [==============================] - 18s 2ms/step - loss: 0.2078 - accuracy: 0.9243
# Epoch 45/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2075 - accuracy: 0.9244
# Epoch 46/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2074 - accuracy: 0.9246
# Epoch 47/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2071 - accuracy: 0.9246
# Epoch 48/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2069 - accuracy: 0.9249
# Epoch 49/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2066 - accuracy: 0.9249
# Epoch 50/100
# 7016/7016 [==============================] - 19s 3ms/step - loss: 0.2065 - accuracy: 0.9252
# Epoch 51/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2064 - accuracy: 0.9252
# Epoch 52/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2063 - accuracy: 0.9253
# Epoch 53/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2059 - accuracy: 0.9253
# Epoch 54/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2059 - accuracy: 0.9252
# Epoch 55/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2057 - accuracy: 0.9255
# Epoch 56/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2056 - accuracy: 0.9255
# Epoch 57/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2053 - accuracy: 0.9257
# Epoch 58/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2052 - accuracy: 0.9258
# Epoch 59/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2049 - accuracy: 0.9257
# Epoch 60/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2051 - accuracy: 0.9259
# Epoch 61/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2047 - accuracy: 0.9259
# Epoch 62/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2046 - accuracy: 0.9258
# Epoch 63/100
# 7016/7016 [==============================] - 20s 3ms/step - loss: 0.2045 - accuracy: 0.9260
# Epoch 64/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2045 - accuracy: 0.9262
# Epoch 65/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2043 - accuracy: 0.9261
# Epoch 66/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2041 - accuracy: 0.9263
# Epoch 67/100
# 7016/7016 [==============================] - 18s 2ms/step - loss: 0.2042 - accuracy: 0.9264
# Epoch 68/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2040 - accuracy: 0.9262
# Epoch 69/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2038 - accuracy: 0.9264
# Epoch 70/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2037 - accuracy: 0.9262
# Epoch 71/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2034 - accuracy: 0.9264
# Epoch 72/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2036 - accuracy: 0.9265
# Epoch 73/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2034 - accuracy: 0.9265
# Epoch 74/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2032 - accuracy: 0.9266
# Epoch 75/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2032 - accuracy: 0.9267
# Epoch 76/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2031 - accuracy: 0.9268
# Epoch 77/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2030 - accuracy: 0.9266
# Epoch 78/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2030 - accuracy: 0.9265
# Epoch 79/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2028 - accuracy: 0.9265
# Epoch 80/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2028 - accuracy: 0.9269
# Epoch 81/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2025 - accuracy: 0.9268
# Epoch 82/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2027 - accuracy: 0.9267
# Epoch 83/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2025 - accuracy: 0.9268
# Epoch 84/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2025 - accuracy: 0.9270
# Epoch 85/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2024 - accuracy: 0.9269
# Epoch 86/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2023 - accuracy: 0.9268
# Epoch 87/100
# 7016/7016 [==============================] - 19s 3ms/step - loss: 0.2021 - accuracy: 0.9272
# Epoch 88/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2023 - accuracy: 0.9270
# Epoch 89/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2020 - accuracy: 0.9271
# Epoch 90/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2020 - accuracy: 0.9271
# Epoch 91/100
# 7016/7016 [==============================] - 16s 2ms/step - loss: 0.2020 - accuracy: 0.9271
# Epoch 92/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2018 - accuracy: 0.9271
# Epoch 93/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2016 - accuracy: 0.9272
# Epoch 94/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2016 - accuracy: 0.9273
# Epoch 95/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2018 - accuracy: 0.9274
# Epoch 96/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2016 - accuracy: 0.9272
# Epoch 97/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2015 - accuracy: 0.9271
# Epoch 98/100
# 7016/7016 [==============================] - 17s 2ms/step - loss: 0.2015 - accuracy: 0.9274
# Epoch 99/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2015 - accuracy: 0.9273
# Epoch 100/100
# 7016/7016 [==============================] - 18s 3ms/step - loss: 0.2013 - accuracy: 0.9273

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2339/2339 - 4s - loss: 0.2541 - accuracy: 0.9166 - 4s/epoch - 2ms/step
# Loss: 0.2541004419326782, Accuracy: 0.9165953993797302

# %% [markdown]
# # Model Evaluation
