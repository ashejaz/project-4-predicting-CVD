# %%
# Import dependencies
import pandas as pd
import tensorflow as tf
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier

# %%
# Read in the cardiovascular dataset from Google Sheets
cvd_df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vSDchXr1EhgCSsxlxJ3lWPhh1kT5EJS3yv4DJ2YLeMIC3y4uq-Pp4EQknrs9zAiaI3ulne2Jyi6gR6G/pub?gid=602879552&single=true&output=csv")
cvd_df.head()
# Out:
#   general_health                  checkup exercise heart_disease skin_cancer  \
# 0           Poor  Within the past 2 years       No            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 2      Very Good     Within the past year      Yes            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 4           Good     Within the past year       No            No          No
#
#   other_cancer depression diabetes arthritis     sex age_category  height_cm  \
# 0           No         No       No       Yes  Female        70-74        150
# 1           No         No      Yes        No  Female        70-74        165
# 2           No         No      Yes        No  Female        60-64        163
# 3           No         No      Yes        No    Male        75-79        180
# 4           No         No       No        No    Male          80+        191
#
#    weight_kg    bmi smoking_history  alcohol_consumption  fruit_consumption  \
# 0      32.66  14.54             Yes                    0                 30
# 1      77.11  28.29              No                    0                 30
# 2      88.45  33.47              No                    4                 12
# 3      93.44  28.73              No                    0                 30
# 4      88.45  24.37             Yes                    0                  8
#
#    green_vegetables_consumption  friedpotato_consumption
# 0                            16                       12
# 1                             0                        4
# 2                             3                       16
# 3                            30                        8
# 4                             4                        0

# %% [markdown]
# # Data Preprocessing

# %%
# Check datatypes
cvd_df.dtypes
# Out:
# general_health                   object
# checkup                          object
# exercise                         object
# heart_disease                    object
# skin_cancer                      object
# other_cancer                     object
# depression                       object
# diabetes                         object
# arthritis                        object
# sex                              object
# age_category                     object
# height_cm                         int64
# weight_kg                       float64
# bmi                             float64
# smoking_history                  object
# alcohol_consumption               int64
# fruit_consumption                 int64
# green_vegetables_consumption      int64
# friedpotato_consumption           int64
# dtype: object

# %%
# Define categorical columns for encoding and numeric columns for scaling
categorical_cols = cvd_df.dtypes[cvd_df.dtypes == 'object'].index.tolist()

numeric_cols = cvd_df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# %%
# Check value counts of target variable
cvd_df['heart_disease'].value_counts()
# Out:
# No     275231
# Yes     24081
# Name: heart_disease, dtype: int64

# %% [markdown]
# The proportion of positive instances of heart disease ('Yes') to negative instances ('No') is heavily imbalanced. Initial testing revealed that this would result in a model that can accurately predict if a patient does not have heart diease, but is not able to accurately predict if a person does have disease. For this reason, we have decided to cut down the majority class, in this instance the 'No' category, to make the classes more balanced.
#
# We have chosen to remove all datapoints that lay outside of 1 standard deviation from the mean of the data.

# %%
# Calculate mean and standard deviation for numeric columns
means = cvd_df[numeric_cols].mean()
stds = cvd_df[numeric_cols].std()

# Define the number of standard deviations for the threshold
threshold_std = 1

# Identify outliers for numeric columns based on standard deviations
outliers = ((cvd_df[numeric_cols] - means).abs() > threshold_std * stds).any(axis=1)

# Filter rows where 'heart_disease' is 'No' and not an outlier
filtered_rows = (~outliers) | (cvd_df['heart_disease'] == 'Yes')

# Create the filtered DataFrame
cvd_df_filtered = cvd_df[filtered_rows]

# %%
# Re-check value counts of target variable
cvd_df_filtered['heart_disease'].value_counts()
# Out:
# No     55566
# Yes    24081
# Name: heart_disease, dtype: int64

# %% [markdown]
# The classes in the target variable are now significantly closer to being balanced than previously.

# %%
# Encode categorical columns using get_dummies
encoded_df = pd.get_dummies(cvd_df_filtered, columns=categorical_cols, drop_first=False)
encoded_df.head()
# Out:
#    height_cm  weight_kg    bmi  alcohol_consumption  fruit_consumption  \
# 1        165      77.11  28.29                    0                 30
# 3        180      93.44  28.73                    0                 30
# 6        175      69.85  22.74                    0                 16
# 8        163      72.57  27.46                    0                 12
# 9        163      91.63  34.67                    0                 12
#
#    green_vegetables_consumption  friedpotato_consumption  \
# 1                             0                        4
# 3                            30                        8
# 6                             8                        0
# 8                            12                        4
# 9                            12                        1
#
#    general_health_Excellent  general_health_Fair  general_health_Good  ...  \
# 1                         0                    0                    0  ...
# 3                         0                    0                    0  ...
# 6                         0                    1                    0  ...
# 8                         0                    1                    0  ...
# 9                         0                    1                    0  ...
#
#    age_category_45-49  age_category_50-54  age_category_55-59  \
# 1                   0                   0                   0
# 3                   0                   0                   0
# 6                   0                   0                   0
# 8                   0                   0                   0
# 9                   0                   0                   0
#
#    age_category_60-64  age_category_65-69  age_category_70-74  \
# 1                   0                   0                   1
# 3                   0                   0                   0
# 6                   1                   0                   0
# 8                   0                   1                   0
# 9                   0                   0                   1
#
#    age_category_75-79  age_category_80+  smoking_history_No  \
# 1                   0                 0                   1
# 3                   1                 0                   1
# 6                   0                 0                   0
# 8                   0                 0                   0
# 9                   0                 0                   1
#
#    smoking_history_Yes
# 1                    0
# 3                    0
# 6                    1
# 8                    1
# 9                    0
#
# [5 rows x 48 columns]

# %%
# Scale numerical columns using StandardScaler
scaler = StandardScaler()
encoded_df[numeric_cols] = scaler.fit_transform(encoded_df[numeric_cols])
encoded_df.head()
# Out:
#    height_cm  weight_kg       bmi  alcohol_consumption  fruit_consumption  \
# 1  -0.832260  -0.393566 -0.000590            -0.556508           0.413674
# 3   1.184427   0.704890  0.095604            -0.556508           0.413674
# 6   0.512198  -0.881918 -1.213951            -0.556508          -0.472114
# 8  -1.101152  -0.698954 -0.182048            -0.556508          -0.725196
# 9  -1.101152   0.583139  1.394228            -0.556508          -0.725196
#
#    green_vegetables_consumption  friedpotato_consumption  \
# 1                     -1.250370                -0.166917
# 3                      1.515171                 0.547281
# 6                     -0.512893                -0.881115
# 8                     -0.144154                -0.166917
# 9                     -0.144154                -0.702566
#
#    general_health_Excellent  general_health_Fair  general_health_Good  ...  \
# 1                         0                    0                    0  ...
# 3                         0                    0                    0  ...
# 6                         0                    1                    0  ...
# 8                         0                    1                    0  ...
# 9                         0                    1                    0  ...
#
#    age_category_45-49  age_category_50-54  age_category_55-59  \
# 1                   0                   0                   0
# 3                   0                   0                   0
# 6                   0                   0                   0
# 8                   0                   0                   0
# 9                   0                   0                   0
#
#    age_category_60-64  age_category_65-69  age_category_70-74  \
# 1                   0                   0                   1
# 3                   0                   0                   0
# 6                   1                   0                   0
# 8                   0                   1                   0
# 9                   0                   0                   1
#
#    age_category_75-79  age_category_80+  smoking_history_No  \
# 1                   0                 0                   1
# 3                   1                 0                   1
# 6                   0                 0                   0
# 8                   0                 0                   0
# 9                   0                 0                   1
#
#    smoking_history_Yes
# 1                    0
# 3                    0
# 6                    1
# 8                    1
# 9                    0
#
# [5 rows x 48 columns]

# %%
# Assign the target variable 'heart_disease' to y
y = encoded_df['heart_disease_Yes']

# Assign the remaining columns (features) to X
X = encoded_df.drop(columns=['heart_disease_Yes', 'heart_disease_No'])

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Checking the value counts of the y variable
y_train.value_counts()
# Out:
# 0    41653
# 1    18082
# Name: heart_disease_Yes, dtype: int64

# %%
# Fit a random over sampler model to the training data to balance out the classes fully
ROS = RandomOverSampler(random_state=78)
X_train_resampled, y_train_resampled = ROS.fit_resample(X_train, y_train)

# %%
# Re-check the value counts to ensure oversampling has worked
y_train_resampled.value_counts()
# Out:
# 1    41653
# 0    41653
# Name: heart_disease_Yes, dtype: int64

# %% [markdown]
# # Model 1: Logistic Regression

# %% [markdown]
# # Model 2: Support Vector Machine

# %%
# Initialise model and fit to the training data
model = SVC(kernel='linear')
model.fit(X_train_resampled, y_train_resampled)

# %%
# Validate with the test data
model.score(X_test, y_test)

# %%
# Save model's predicitons for the test data
training_predictions = model.predict(X_test)

# %%
# Create a confusion matrix
training_matrix = confusion_matrix(y_test, training_predictions)
pd.DataFrame(training_matrix, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

# %%
# Target prediciton categories
target_names = ["No Heart Disease", "Heart Disease"]
# Print a classification report
print(classification_report(y_test, training_predictions,
                            target_names=target_names))

# %% [markdown]
# # Model 3: Decision Tree

# %% [markdown]
# # Model 4: Random Forest

# %% [markdown]
# # Model 5: Neural Network

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = X_train_resampled.shape[1]
hidden_nodes_layer1 =  64
hidden_nodes_layer2 = 64

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                3008
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 7233 (28.25 KB)
# Trainable params: 7233 (28.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_resampled, y_train_resampled, epochs=100, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 2604/2604 [==============================] - 9s 3ms/step - loss: 0.3076 - accuracy: 0.8588 - val_loss: 0.2731 - val_accuracy: 0.8789
# Epoch 2/100
# 2604/2604 [==============================] - 8s 3ms/step - loss: 0.2677 - accuracy: 0.8756 - val_loss: 0.2531 - val_accuracy: 0.8919
# Epoch 3/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.2500 - accuracy: 0.8847 - val_loss: 0.2287 - val_accuracy: 0.9045
# Epoch 4/100
# 2604/2604 [==============================] - 7s 3ms/step - loss: 0.2413 - accuracy: 0.8879 - val_loss: 0.2365 - val_accuracy: 0.8959
# Epoch 5/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.2343 - accuracy: 0.8910 - val_loss: 0.2379 - val_accuracy: 0.9001
# Epoch 6/100
# 2604/2604 [==============================] - 8s 3ms/step - loss: 0.2294 - accuracy: 0.8930 - val_loss: 0.2295 - val_accuracy: 0.8969
# Epoch 7/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.2250 - accuracy: 0.8950 - val_loss: 0.2118 - val_accuracy: 0.9109
# Epoch 8/100
# 2604/2604 [==============================] - 7s 3ms/step - loss: 0.2207 - accuracy: 0.8975 - val_loss: 0.2313 - val_accuracy: 0.9061
# Epoch 9/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.2167 - accuracy: 0.8991 - val_loss: 0.2313 - val_accuracy: 0.8994
# Epoch 10/100
# 2604/2604 [==============================] - 7s 3ms/step - loss: 0.2134 - accuracy: 0.9019 - val_loss: 0.2267 - val_accuracy: 0.9043
# Epoch 11/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.2102 - accuracy: 0.9028 - val_loss: 0.2331 - val_accuracy: 0.9020
# Epoch 12/100
# 2604/2604 [==============================] - 7s 3ms/step - loss: 0.2068 - accuracy: 0.9049 - val_loss: 0.2607 - val_accuracy: 0.8828
# Epoch 13/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.2037 - accuracy: 0.9067 - val_loss: 0.2327 - val_accuracy: 0.8994
# Epoch 14/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.2005 - accuracy: 0.9088 - val_loss: 0.2313 - val_accuracy: 0.9031
# Epoch 15/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1980 - accuracy: 0.9098 - val_loss: 0.2414 - val_accuracy: 0.8960
# Epoch 16/100
# 2604/2604 [==============================] - 7s 3ms/step - loss: 0.1953 - accuracy: 0.9108 - val_loss: 0.2308 - val_accuracy: 0.9030
# Epoch 17/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.
100
# 2604/2604 [==============================] - 7s 3ms/step - loss: 0.1180 - accuracy: 0.9488 - val_loss: 0.3790 - val_accuracy: 0.8864
# Epoch 81/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1182 - accuracy: 0.9493 - val_loss: 0.3793 - val_accuracy: 0.8853
# Epoch 82/100
# 2604/2604 [==============================] - 7s 3ms/step - loss: 0.1170 - accuracy: 0.9508 - val_loss: 0.3901 - val_accuracy: 0.8768
# Epoch 83/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1174 - accuracy: 0.9503 - val_loss: 0.3837 - val_accuracy: 0.8907
# Epoch 84/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1170 - accuracy: 0.9502 - val_loss: 0.3750 - val_accuracy: 0.8922
# Epoch 85/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1153 - accuracy: 0.9506 - val_loss: 0.3918 - val_accuracy: 0.8793
# Epoch 86/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1168 - accuracy: 0.9505 - val_loss: 0.3922 - val_accuracy: 0.8843
# Epoch 87/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1148 - accuracy: 0.9515 - val_loss: 0.3974 - val_accuracy: 0.8879
# Epoch 88/100
# 2604/2604 [==============================] - 7s 3ms/step - loss: 0.1150 - accuracy: 0.9509 - val_loss: 0.3898 - val_accuracy: 0.8901
# Epoch 89/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1139 - accuracy: 0.9518 - val_loss: 0.3964 - val_accuracy: 0.8899
# Epoch 90/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1147 - accuracy: 0.9506 - val_loss: 0.3954 - val_accuracy: 0.8896
# Epoch 91/100
# 2604/2604 [==============================] - 7s 3ms/step - loss: 0.1145 - accuracy: 0.9513 - val_loss: 0.4075 - val_accuracy: 0.8870
# Epoch 92/100
# 2604/2604 [==============================] - 7s 3ms/step - loss: 0.1136 - accuracy: 0.9516 - val_loss: 0.4015 - val_accuracy: 0.8858
# Epoch 93/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1126 - accuracy: 0.9520 - val_loss: 0.4241 - val_accuracy: 0.8786
# Epoch 94/100
# 2604/2604 [==============================] - 7s 2ms/step - loss: 0.1130 - accuracy: 0.9518 - val_loss: 0.4112 - val_accuracy: 0.8882
# Epoch 95/100
# 2604/2604 [==============================] - 7s 3ms/step - loss: 0.1127 - accuracy: 0.9521 - val_loss: 0.4105 - val_accuracy: 0.8879
# Epoch 96/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1125 - accuracy: 0.9529 - val_loss: 0.4134 - val_accuracy: 0.8821
# Epoch 97/100
# 2604/2604 [==============================] - 7s 3ms/step - loss: 0.1112 - accuracy: 0.9533 - val_loss: 0.4148 - val_accuracy: 0.8854
# Epoch 98/100
# 2604/2604 [==============================] - 7s 3ms/step - loss: 0.1112 - accuracy: 0.9526 - val_loss: 0.4019 - val_accuracy: 0.8901
# Epoch 99/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1104 - accuracy: 0.9531 - val_loss: 0.4229 - val_accuracy: 0.8851
# Epoch 100/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1108 - accuracy: 0.9533 - val_loss: 0.4075 - val_accuracy: 0.8885

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 623/623 - 1s - loss: 0.4075 - accuracy: 0.8885 - 774ms/epoch - 1ms/step
# Loss: 0.40749412775039673, Accuracy: 0.8884592056274414

# %% [markdown]
# As the number of epochs increases, the training accuracy increases and the training loss decreases indicating that the model is learning well on the training data. However, after around 20 epochs we see that the validation accuracy plateaus and starts to decrease, and the validation loss appears to increase. This suggests that the model is overfitting and though it performs well on the training data, it may struggle on unseen data.

# %%
# Make predictions using the trained model
# Setting threshold of 0.5 since our model utilises sigmoid activation on a binary classification problem
y_pred = (nn.predict(X_test) > 0.5).astype(np.int32)

# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
# 623/623 [==============================] - 1s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92     13913
#            1       0.81      0.83      0.82      5999
#
#     accuracy                           0.89     19912
#    macro avg       0.87      0.87      0.87     19912
# weighted avg       0.89      0.89      0.89     19912

# %%
# Download h5 file
from google.colab import files
nn.save('cvd_nn_model1.h5')
files.download("cvd_nn_model1.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
