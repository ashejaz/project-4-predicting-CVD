# %%
# Import dependencies
import pandas as pd
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier

# %%
# Read in the cardiovascular dataset from Google Sheets
cvd_df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vSDchXr1EhgCSsxlxJ3lWPhh1kT5EJS3yv4DJ2YLeMIC3y4uq-Pp4EQknrs9zAiaI3ulne2Jyi6gR6G/pub?gid=602879552&single=true&output=csv")
cvd_df.head()
# Out:
#   general_health                  checkup exercise heart_disease skin_cancer  \
# 0           Poor  Within the past 2 years       No            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 2      Very Good     Within the past year      Yes            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 4           Good     Within the past year       No            No          No
#
#   other_cancer depression diabetes arthritis     sex age_category  height_cm  \
# 0           No         No       No       Yes  Female        70-74        150
# 1           No         No      Yes        No  Female        70-74        165
# 2           No         No      Yes        No  Female        60-64        163
# 3           No         No      Yes        No    Male        75-79        180
# 4           No         No       No        No    Male          80+        191
#
#    weight_kg    bmi smoking_history  alcohol_consumption  fruit_consumption  \
# 0      32.66  14.54             Yes                    0                 30
# 1      77.11  28.29              No                    0                 30
# 2      88.45  33.47              No                    4                 12
# 3      93.44  28.73              No                    0                 30
# 4      88.45  24.37             Yes                    0                  8
#
#    green_vegetables_consumption  friedpotato_consumption
# 0                            16                       12
# 1                             0                        4
# 2                             3                       16
# 3                            30                        8
# 4                             4                        0

# %% [markdown]
# # Data Preprocessing

# %%
# Check datatypes
cvd_df.dtypes
# Out:
# general_health                   object
# checkup                          object
# exercise                         object
# heart_disease                    object
# skin_cancer                      object
# other_cancer                     object
# depression                       object
# diabetes                         object
# arthritis                        object
# sex                              object
# age_category                     object
# height_cm                         int64
# weight_kg                       float64
# bmi                             float64
# smoking_history                  object
# alcohol_consumption               int64
# fruit_consumption                 int64
# green_vegetables_consumption      int64
# friedpotato_consumption           int64
# dtype: object

# %%
# Define categorical columns for encoding and numeric columns for scaling
categorical_cols = cvd_df.dtypes[cvd_df.dtypes == 'object'].index.tolist()

numeric_cols = cvd_df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# %%
# Check value counts of target variable
cvd_df['heart_disease'].value_counts()
# Out:
# No     275231
# Yes     24081
# Name: heart_disease, dtype: int64

# %% [markdown]
# The proportion of positive instances of heart disease ('Yes') to negative instances ('No') is heavily imbalanced. Initial testing revealed that this would result in a model that can accurately predict if a patient does not have heart diease, but is not able to accurately predict if a person does have disease. For this reason, we have decided to cut down the majority class, in this instance the 'No' category, to make the classes more balanced.
#
# We have chosen to remove all datapoints that lay outside of 1 standard deviation from the mean of the data.

# %%
# Calculate mean and standard deviation for numeric columns
means = cvd_df[numeric_cols].mean()
stds = cvd_df[numeric_cols].std()

# Define the number of standard deviations for the threshold
threshold_std = 1

# Identify outliers for numeric columns based on standard deviations
outliers = ((cvd_df[numeric_cols] - means).abs() > threshold_std * stds).any(axis=1)

# Filter rows where 'heart_disease' is 'No' and not an outlier
filtered_rows = (~outliers) | (cvd_df['heart_disease'] == 'Yes')

# Create the filtered DataFrame
cvd_df_filtered = cvd_df[filtered_rows]

# %%
# Re-check value counts of target variable
cvd_df_filtered['heart_disease'].value_counts()
# Out:
# No     55566
# Yes    24081
# Name: heart_disease, dtype: int64

# %% [markdown]
# The classes in the target variable are now significantly closer to being balanced than previously.

# %%
# Encode categorical columns using get_dummies
encoded_df = pd.get_dummies(cvd_df_filtered, columns=categorical_cols, drop_first=False)
encoded_df.head()
# Out:
#    height_cm  weight_kg    bmi  alcohol_consumption  fruit_consumption  \
# 1        165      77.11  28.29                    0                 30
# 3        180      93.44  28.73                    0                 30
# 6        175      69.85  22.74                    0                 16
# 8        163      72.57  27.46                    0                 12
# 9        163      91.63  34.67                    0                 12
#
#    green_vegetables_consumption  friedpotato_consumption  \
# 1                             0                        4
# 3                            30                        8
# 6                             8                        0
# 8                            12                        4
# 9                            12                        1
#
#    general_health_Excellent  general_health_Fair  general_health_Good  ...  \
# 1                         0                    0                    0  ...
# 3                         0                    0                    0  ...
# 6                         0                    1                    0  ...
# 8                         0                    1                    0  ...
# 9                         0                    1                    0  ...
#
#    age_category_45-49  age_category_50-54  age_category_55-59  \
# 1                   0                   0                   0
# 3                   0                   0                   0
# 6                   0                   0                   0
# 8                   0                   0                   0
# 9                   0                   0                   0
#
#    age_category_60-64  age_category_65-69  age_category_70-74  \
# 1                   0                   0                   1
# 3                   0                   0                   0
# 6                   1                   0                   0
# 8                   0                   1                   0
# 9                   0                   0                   1
#
#    age_category_75-79  age_category_80+  smoking_history_No  \
# 1                   0                 0                   1
# 3                   1                 0                   1
# 6                   0                 0                   0
# 8                   0                 0                   0
# 9                   0                 0                   1
#
#    smoking_history_Yes
# 1                    0
# 3                    0
# 6                    1
# 8                    1
# 9                    0
#
# [5 rows x 48 columns]

# %%
# Scale numerical columns using StandardScaler
scaler = StandardScaler()
encoded_df[numeric_cols] = scaler.fit_transform(encoded_df[numeric_cols])
encoded_df.head()
# Out:
#    height_cm  weight_kg       bmi  alcohol_consumption  fruit_consumption  \
# 1  -0.832260  -0.393566 -0.000590            -0.556508           0.413674
# 3   1.184427   0.704890  0.095604            -0.556508           0.413674
# 6   0.512198  -0.881918 -1.213951            -0.556508          -0.472114
# 8  -1.101152  -0.698954 -0.182048            -0.556508          -0.725196
# 9  -1.101152   0.583139  1.394228            -0.556508          -0.725196
#
#    green_vegetables_consumption  friedpotato_consumption  \
# 1                     -1.250370                -0.166917
# 3                      1.515171                 0.547281
# 6                     -0.512893                -0.881115
# 8                     -0.144154                -0.166917
# 9                     -0.144154                -0.702566
#
#    general_health_Excellent  general_health_Fair  general_health_Good  ...  \
# 1                         0                    0                    0  ...
# 3                         0                    0                    0  ...
# 6                         0                    1                    0  ...
# 8                         0                    1                    0  ...
# 9                         0                    1                    0  ...
#
#    age_category_45-49  age_category_50-54  age_category_55-59  \
# 1                   0                   0                   0
# 3                   0                   0                   0
# 6                   0                   0                   0
# 8                   0                   0                   0
# 9                   0                   0                   0
#
#    age_category_60-64  age_category_65-69  age_category_70-74  \
# 1                   0                   0                   1
# 3                   0                   0                   0
# 6                   1                   0                   0
# 8                   0                   1                   0
# 9                   0                   0                   1
#
#    age_category_75-79  age_category_80+  smoking_history_No  \
# 1                   0                 0                   1
# 3                   1                 0                   1
# 6                   0                 0                   0
# 8                   0                 0                   0
# 9                   0                 0                   1
#
#    smoking_history_Yes
# 1                    0
# 3                    0
# 6                    1
# 8                    1
# 9                    0
#
# [5 rows x 48 columns]

# %%
# Assign the target variable 'heart_disease' to y
y = encoded_df['heart_disease_Yes']

# Assign the remaining columns (features) to X
X = encoded_df.drop(columns=['heart_disease_Yes', 'heart_disease_No'])

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Checking the value counts of the y variable
y_train.value_counts()
# Out:
# 0    41653
# 1    18082
# Name: heart_disease_Yes, dtype: int64

# %%
# Fit a random over sampler model to the training data to balance out the classes fully
ROS = RandomOverSampler(random_state=78)
X_train_resampled, y_train_resampled = ROS.fit_resample(X_train, y_train)

# %%
# Re-check the value counts to ensure oversampling has worked
y_train_resampled.value_counts()
# Out:
# 1    41653
# 0    41653
# Name: heart_disease_Yes, dtype: int64

# %% [markdown]
# # Model 1: Logistic Regression

# %% [markdown]
# # Model 2: Support Vector Machine

# %%
# Initialise model and fit to the training data
model = SVC(kernel='linear')
model.fit(X_train_resampled, y_train_resampled)
# Out:
# SVC(kernel='linear')

# %%
# Validate with the test data
model.score(X_test, y_test)
# Out:
# 0.7871132985134592

# %%
# Save model's predicitons for the test data
training_predictions = model.predict(X_test)

# %%
# Create a confusion matrix
training_matrix = confusion_matrix(y_test, training_predictions)
pd.DataFrame(training_matrix, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])
# Out:
#           Predicted 0  Predicted 1
# Actual 0        10845         3068
# Actual 1         1171         4828

# %%
# Target prediciton categories
target_names = ["No Heart Disease", "Heart Disease"]
# Print a classification report
print(classification_report(y_test, training_predictions,
                            target_names=target_names))
# Out:
#                   precision    recall  f1-score   support
#
# No Heart Disease       0.90      0.78      0.84     13913
#    Heart Disease       0.61      0.80      0.69      5999
#
#         accuracy                           0.79     19912
#        macro avg       0.76      0.79      0.77     19912
#     weighted avg       0.81      0.79      0.79     19912

# %% [markdown]
# # Model 3: Decision Tree

# %% [markdown]
# # Model 4: Random Forest

# %% [markdown]
# # Model 5: Neural Network

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = X_train_resampled.shape[1]
hidden_nodes_layer1 =  64
hidden_nodes_layer2 = 64

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                3008
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 7233 (28.25 KB)
# Trainable params: 7233 (28.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_resampled, y_train_resampled, epochs=100)
# Out:
# Epoch 1/100
# 2604/2604 [==============================] - 10s 3ms/step - loss: 0.3109 - accuracy: 0.8566
# Epoch 2/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.2711 - accuracy: 0.8739
# Epoch 3/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.2517 - accuracy: 0.8832
# Epoch 4/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.2409 - accuracy: 0.8890
# Epoch 5/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.2342 - accuracy: 0.8907
# Epoch 6/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.2290 - accuracy: 0.8932
# Epoch 7/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.2253 - accuracy: 0.8952
# Epoch 8/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.2223 - accuracy: 0.8965
# Epoch 9/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.2185 - accuracy: 0.8987
# Epoch 10/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.2154 - accuracy: 0.8997
# Epoch 11/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.2121 - accuracy: 0.9011
# Epoch 12/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.2086 - accuracy: 0.9034
# Epoch 13/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.2051 - accuracy: 0.9049
# Epoch 14/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.2024 - accuracy: 0.9068
# Epoch 15/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1994 - accuracy: 0.9077
# Epoch 16/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1970 - accuracy: 0.9102
# Epoch 17/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1943 - accuracy: 0.9105
# Epoch 18/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1917 - accuracy: 0.9120
# Epoch 19/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1891 - accuracy: 0.9133
# Epoch 20/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1864 - accuracy: 0.9138
# Epoch 21/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1843 - accuracy: 0.9147
# Epoch 22/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1820 - accuracy: 0.9169
# Epoch 23/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1799 - accuracy: 0.9179
# Epoch 24/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1774 - accuracy: 0.9190
# Epoch 25/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1755 - accuracy: 0.9197
# Epoch 26/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1740 - accuracy: 0.9215
# Epoch 27/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1714 - accuracy: 0.9224
# Epoch 28/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1697 - accuracy: 0.9238
# Epoch 29/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1681 - accuracy: 0.9245
# Epoch 30/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1661 - accuracy: 0.9249
# Epoch 31/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1644 - accuracy: 0.9272
# Epoch 32/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1625 - accuracy: 0.9279
# Epoch 33/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1613 - accuracy: 0.9271
# Epoch 34/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1601 - accuracy: 0.9280
# Epoch 35/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1581 - accuracy: 0.9293
# Epoch 36/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1567 - accuracy: 0.9298
# Epoch 37/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1551 - accuracy: 0.9305
# Epoch 38/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1547 - accuracy: 0.9314
# Epoch 39/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1527 - accuracy: 0.9323
# Epoch 40/100
# 2604/2604 [==============================] - 7s 3ms/step - loss: 0.1511 - accuracy: 0.9327
# Epoch 41/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1509 - accuracy: 0.9335
# Epoch 42/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1502 - accuracy: 0.9340
# Epoch 43/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1486 - accuracy: 0.9346
# Epoch 44/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1475 - accuracy: 0.9351
# Epoch 45/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1475 - accuracy: 0.9343
# Epoch 46/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1451 - accuracy: 0.9364
# Epoch 47/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1446 - accuracy: 0.9370
# Epoch 48/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1439 - accuracy: 0.9372
# Epoch 49/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1429 - accuracy: 0.9379
# Epoch 50/100
# 2604/2604 [==============================] - 9s 3ms/step - loss: 0.1430 - accuracy: 0.9373
# Epoch 51/100
# 2604/2604 [==============================] - 7s 3ms/step - loss: 0.1408 - accuracy: 0.9383
# Epoch 52/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1407 - accuracy: 0.9390
# Epoch 53/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1405 - accuracy: 0.9394
# Epoch 54/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1384 - accuracy: 0.9395
# Epoch 55/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1383 - accuracy: 0.9400
# Epoch 56/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1366 - accuracy: 0.9408
# Epoch 57/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1371 - accuracy: 0.9410
# Epoch 58/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1354 - accuracy: 0.9412
# Epoch 59/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1352 - accuracy: 0.9411
# Epoch 60/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1343 - accuracy: 0.9413
# Epoch 61/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1339 - accuracy: 0.9422
# Epoch 62/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1330 - accuracy: 0.9429
# Epoch 63/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1313 - accuracy: 0.9431
# Epoch 64/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1318 - accuracy: 0.9440
# Epoch 65/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1300 - accuracy: 0.9444
# Epoch 66/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1300 - accuracy: 0.9447
# Epoch 67/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1291 - accuracy: 0.9438
# Epoch 68/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1280 - accuracy: 0.9450
# Epoch 69/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1278 - accuracy: 0.9451
# Epoch 70/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1272 - accuracy: 0.9452
# Epoch 71/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1265 - accuracy: 0.9454
# Epoch 72/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1267 - accuracy: 0.9457
# Epoch 73/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1252 - accuracy: 0.9457
# Epoch 74/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1253 - accuracy: 0.9457
# Epoch 75/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1247 - accuracy: 0.9464
# Epoch 76/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1232 - accuracy: 0.9473
# Epoch 77/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1234 - accuracy: 0.9475
# Epoch 78/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1236 - accuracy: 0.9471
# Epoch 79/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1209 - accuracy: 0.9488
# Epoch 80/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1219 - accuracy: 0.9485
# Epoch 81/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1212 - accuracy: 0.9482
# Epoch 82/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1204 - accuracy: 0.9478
# Epoch 83/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1201 - accuracy: 0.9489
# Epoch 84/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1197 - accuracy: 0.9490
# Epoch 85/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1189 - accuracy: 0.9496
# Epoch 86/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1185 - accuracy: 0.9495
# Epoch 87/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1174 - accuracy: 0.9500
# Epoch 88/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1179 - accuracy: 0.9495
# Epoch 89/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1173 - accuracy: 0.9501
# Epoch 90/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1172 - accuracy: 0.9501
# Epoch 91/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1164 - accuracy: 0.9500
# Epoch 92/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1144 - accuracy: 0.9515
# Epoch 93/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1152 - accuracy: 0.9514
# Epoch 94/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1144 - accuracy: 0.9516
# Epoch 95/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1147 - accuracy: 0.9512
# Epoch 96/100
# 2604/2604 [==============================] - 6s 2ms/step - loss: 0.1126 - accuracy: 0.9516
# Epoch 97/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1138 - accuracy: 0.9514
# Epoch 98/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1131 - accuracy: 0.9518
# Epoch 99/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1130 - accuracy: 0.9510
# Epoch 100/100
# 2604/2604 [==============================] - 5s 2ms/step - loss: 0.1127 - accuracy: 0.9517

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 623/623 - 1s - loss: 0.3955 - accuracy: 0.8878 - 1s/epoch - 2ms/step
# Loss: 0.39546889066696167, Accuracy: 0.8878063559532166
